# %%
# !pip install tweepy
# !pip install snscrape
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
import string
import sys,csv,re
# Creating list to append tweet data to
tweets_list3 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('Covid 19 vaccination until:2020-10-11').get_items()):
    if i>5000:
        break
    tweets_list3.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.likeCount, tweet.user.displayname, tweet.lang])
    
# Creating a dataframe from the tweets list above
tweets_df3 = pd.DataFrame(tweets_list3, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Like Count', 'Display Name', 'Language'])

# %%
tweets_df3
# Out:
#                       Datetime             Tweet Id  \
# 0    2020-10-10 22:56:24+00:00  1315063663305330690
# 1    2020-10-10 22:38:18+00:00  1315059108580659202
# 2    2020-10-10 22:32:11+00:00  1315057567454965764
# 3    2020-10-10 22:00:14+00:00  1315049528752513024
# 4    2020-10-10 21:19:17+00:00  1315039221028134912
# ...                        ...                  ...
# 4996 2020-09-12 21:13:16+00:00  1304890848610484229
# 4997 2020-09-12 21:06:38+00:00  1304889178375835650
# 4998 2020-09-12 21:01:22+00:00  1304887851646058498
# 4999 2020-09-12 21:00:43+00:00  1304887691260186624
# 5000 2020-09-12 20:56:06+00:00  1304886528620011527
#
#                                                    Text         Username  \
# 0     Narendra Modi (PM India): Prevent any restrict...    subodha_chand
# 1     @UNITED4000 If you read what Pope Francis are ...         Julija9j
# 2     @bopinion Her Immunity is supposed to happen t...  DivineBloodBook
# ...

# %%
# Creating list to append tweet data to
tweets_list4 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('covid 19 vaccination until:2021-09-12').get_items()):
    if i>5000:
        break
    tweets_list4.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.likeCount, tweet.user.displayname, tweet.lang])
    
# Creating a dataframe from the tweets list above
tweets_df4 = pd.DataFrame(tweets_list4, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Like Count', 'Display Name', 'Language'])

# %%
tweets_df4
# Out:
#                       Datetime             Tweet Id  \
# 0    2021-09-11 23:48:18+00:00  1436839045544488962
# 1    2021-09-11 23:25:59+00:00  1436833430713495552
# 2    2021-09-11 23:25:33+00:00  1436833319644241921
# 3    2021-09-11 22:58:11+00:00  1436826432861138945
# 4    2021-09-11 22:50:07+00:00  1436824403371864071
# ...                        ...                  ...
# 4996 2021-07-03 12:41:47+00:00  1411304161325498376
# 4997 2021-07-03 12:21:51+00:00  1411299145642483715
# 4998 2021-07-03 12:05:19+00:00  1411294984892866561
# 4999 2021-07-03 11:43:49+00:00  1411289573418807296
# 5000 2021-07-03 11:17:47+00:00  1411283023501291528
#
#                                                    Text         Username  \
# 0     Today, the Alpha Omicron chapter of Phi Iota A...         TxstPhiA
# 1     @omicron_8 Context dependent. Social media = a...      hubermanlab
# 2     I enjoyed my last Dad’s Day with @TheHannahLow...     KevinGLowery
# ...

# %%
# Creating list to append tweet data to
tweets_list5 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('covid 19 vaccination until:2021-01-07').get_items()):
    if i>5000:
        break
    tweets_list5.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.likeCount, tweet.user.displayname, tweet.lang])
    
# Creating a dataframe from the tweets list above
tweets_df5 = pd.DataFrame(tweets_list5, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Like Count', 'Display Name', 'Language'])

# %%
tweets_df5
# Out:
#                       Datetime             Tweet Id  \
# 0    2021-01-06 23:58:21+00:00  1346969386406572035
# 1    2021-01-06 23:54:14+00:00  1346968346961567744
# 2    2021-01-06 23:32:05+00:00  1346962776179273731
# 3    2021-01-06 23:14:23+00:00  1346958318393290761
# 4    2021-01-06 23:13:24+00:00  1346958074888728583
# ...                        ...                  ...
# 4996 2020-10-11 18:09:29+00:00  1315353846881890307
# 4997 2020-10-11 17:30:26+00:00  1315344019900293120
# 4998 2020-10-11 17:05:15+00:00  1315337680956338177
# 4999 2020-10-11 17:00:52+00:00  1315336578877796352
# 5000 2020-10-11 16:56:52+00:00  1315335571804352512
#
#                                                    Text         Username  \
# 0     @___omicron___ @KapeMatthew @kdc_md In case yo...   kevin_salmon60
# 1     @___omicron___ @KapeMatthew @kdc_md So that’s ...   kevin_salmon60
# 2     Member of omicron fraternity ke 😂🤣😂🤣😂🤣\n\nI do...   Verraofficial_
# ...

# %%
# Creating list to append tweet data to
tweets_list6 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('covid 19 vaccination until:2021-12-11').get_items()):
    if i>5000:
        break
    tweets_list6.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.likeCount, tweet.user.displayname, tweet.lang])
    
# Creating a dataframe from the tweets list above
tweets_df6 = pd.DataFrame(tweets_list6, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Like Count', 'Display Name', 'Language'])

# %%
# Creating list to append tweet data to
tweets_list7 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('covid 19 vaccination until:2021-12-10').get_items()):
    if i>5000:
        break
    tweets_list7.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.likeCount, tweet.user.displayname, tweet.lang])
    
# Creating a dataframe from the tweets list above
tweets_df7 = pd.DataFrame(tweets_list7, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Like Count', 'Display Name', 'Language'])

# %%
# Creating list to append tweet data to
tweets_list8 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('covid 19 vaccination until:2021-12-9').get_items()):
    if i>10000:
        break
    tweets_list8.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.likeCount, tweet.user.displayname, tweet.lang])
    
# Creating a dataframe from the tweets list above
tweets_df8 = pd.DataFrame(tweets_list8, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Like Count', 'Display Name', 'Language'])

# %%
Tweets_Feb = pd.concat([tweets_df2,tweets_df3,tweets_df4,tweets_df5,tweets_df6,tweets_df7,tweets_df8])
Tweets_Feb.shape
Tweets_Feb.to_csv('Tweets_Ext.csv')

# %%
Tweets_Ext = pd.read_csv('Tweets_Ext.csv')

Tweets_Ext.head()
Tweets_Ext.tail()
# Out:
#        Unnamed: 0                   Datetime             Tweet Id  \
# 40002        9996  2021-12-08 21:26:02+00:00  1468693375415353345
# 40003        9997  2021-12-08 21:26:01+00:00  1468693371896094722
# 40004        9998  2021-12-08 21:26:01+00:00  1468693371774550026
# 40005        9999  2021-12-08 21:26:00+00:00  1468693366787358723
# 40006       10000  2021-12-08 21:26:00+00:00  1468693366548299777
#
#                                                     Text        Username  \
# 40002  Covid Shows Ominous Signs As Winter Sets In; O...   priscilagural
# 40003  Israel mandates longer quarantine for omicron:...      Marianhouk
# 40004  @ZimasaMatiwane @Penxenxe That’s the only expl...  sibabalwengaye
# 40005  @RonaldNHughes Do you know who asked the quest...    Lori25777499
# 40006  The government has introduced restrictions to ...    WyeValleyNHS
#
#        Like Count          Display Name Language
# 40002           2   Cheryl de Boissiere       en
# ...
